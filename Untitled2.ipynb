# %% [markdown]
# <a href="https://colab.research.google.com/github/samhithaPeddireddy/Samhitha_Info5502_Spring2022/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/datasets.zip

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the ten folds.
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds dataset is used in all our experiments.
# (The original paper can be download on canvas)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.
#
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Here, I want to check the non fiction books to read based on their rating.
I used Good reads website to extract data.Good reads contains books of different genres, 
theirs authors and their ratings which are given by user.I first selected the good reads website 
and used web scraping method to extract the same.Firstly, i have imported requests library to read the data from URL and used for loop to go through all the pages present.
Then i have used beautifulsoup library to extract data from html files.
i have created a table to define a table (based on HTML element)for the soup to read,then stored the data like- name of the author,name of the book,
ratings based on HTML elements and appended them.Finally i have used dataframes from pandas library to display it as table.
I have downloaded the data and displayed sample records to check.



'''

# %%
from nltk.corpus import PlaintextCorpusReader
import nltk
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code)

import pandas as pd
import numpy as np


import requests
from bs4 import BeautifulSoup

import re
import time

bookname = []
authorname = []
ratings = []
pagenum= []


for i in range(1,26): # go throught the 23 pages
    start_time = time.time()
    URL = 'https://www.goodreads.com/list/show/10048.Non_fiction_Something_for_Everyone?page={}'.format(i)
    page = requests.get(URL)
    pagecontent = page.text
    soup = BeautifulSoup(pagecontent)
    right_table=soup.find('table', class_='tableList js-dataTooltip')
    
    for row in right_table.findAll("tr"):
        name = row.find('span', attrs = {'itemprop':'name'})
        author = row.find('a', attrs = {'class':'authorName'})
        rating = row.find('span', attrs = {'class':'minirating'})
        bookname.append(name.text)
        authorname.append(author.text)
        ratings.append(rating.text)
        
            
        pagenum.append(i)

    print('Page {} completed in {} seconds'.format(i, time.time()-start_time))

# %%
print(len(bookname))
print(len(authorname))
print(len(ratings))
print(len(pagenum))

# %%
books_df = pd.DataFrame({'BookName':bookname, 'authorname':authorname, 'ratings': ratings, 'PageNo': pagenum})

# %%
books_df.to_csv(r'Users\samhithapeddireddy\Downloads\.csv')

books_df.head()

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''

Please write you answer here:
I have analyzed the marketing dataset from kaggle.This dataset was given to business students for data analysis.It contains data like id,income,number of visits to store,education.
The data quality is good enough to analyse but has a few issues.Firstly there are a few duplicate records(based on customer ID).i will remove the duplicate records using DataFrame.drop_duplicates(subset=None, keep=’first’, inplace=False) from pandas library
There is some missing data (income, number of visits, education)and will remove those rows using heatmap.
The outliers if any can be detected using histogram and box plot and We either drop them or keep them.
There is no proper usage of upper and lower cases It could cause issues.sub_area feature can be used to find out.
i will convert all letters to lower cases or upper cases.There is dollar symbol in fornt of incomes and the same needs to be removed to perform proper computation like averages,sum.
Other parts of data looks fine to me.

# %% [markdown]
# New Section
#
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the ten folds.
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds dataset is used in all our experiments.
# (The original paper can be download on canvas)

# %%
corpus_root1 = '/content/datasets/TwADR-L'
corpus_root2 = '/content/datasets/AskAPatient'
res_df =  pd.DataFrame()
res_df2 =  pd.DataFrame()
for dataset in [corpus_root1, corpus_root2]:
 dfr = pd.DataFrame()
 res={}
 corpus = PlaintextCorpusReader(dataset, '.*txt')#here im using plaintextcorpusreader from nltk to read and save the files
 id_list = corpus.fileids()#using fileids,all the filenames in categories and subcategories are retrieved.
 len_total=len(id_list)#here the total length of files is counted.
 #print(id_list)
 print(len_total)
 #print(os.listdir)

#here i am using for loop to iterate through all the files names.
 for i in id_list:
   var3 = "".join([dataset, "/",i]) 
   r=open(var3,"rt")
   r=var3
   #print(r)
   data=pd.read_csv(r, sep = "\t", header = None, encoding= 'unicode_escape')
   dfr=dfr.append(data)


 dfr['phrase_label']=dfr[1]+" "+dfr[2]
 dfr.columns= ['id', 'label', 'phrase', 'phrase_label']
 dfr = dfr.astype({"id": str})
 for columns in dfr.columns:
  dfr[columns] = dfr[columns].str.lower() 

 dfr = dfr.drop_duplicates('phrase_label')
 res['Unique_phrases'] = str(len(dfr['phrase'].unique()))
 res['Unique_labels'] = str(len(dfr['label'].unique()))
 res['Unique_phrase_label_pairs'] = str(dfr.shape[0])
 df1 = pd.DataFrame(dfr['phrase'].value_counts())
 res['Phrases with multiple labels'] = str(df1[df1['phrase'] > 1].shape[0])
 res['Min examples per label'] = str(dfr['label'].value_counts().values.min())
 res['Max examples per label'] = str(dfr['label'].value_counts().values.max())
 res['Avg examples per label'] = round(dfr['label'].value_counts().mean(),2)
 res_df = res_df.append(res, ignore_index=True)

res_df = res_df.transpose()
# result_df.iloc[0:6].astype(int)

res_df.columns = ['TwADR-L', 'AskAPatient']

res_df



#/content/datasets/AskAPatient/AskAPatient.fold-0.test.txt
# Out:
# 30
# 30
#                              TwADR-L AskAPatient
# Unique_phrases                  2944        4470
# Unique_labels                   2220        1038
# Unique_phrase_label_pairs       3157        4507
# Phrases with multiple labels     173          35
# Min examples per label             1           1
# Max examples per label            36         141
# Avg examples per label          1.42        4.34

# %%
#2)corpus_root1 = '/content/datasets/TwADR-L'
corpus_root2 = '/content/datasets/AskAPatient'
res_df =  pd.DataFrame()
res_df2 =  pd.DataFrame()
for dataset in [corpus_root1, corpus_root2]:
 dfr = pd.DataFrame()
 res={}
 corpus = PlaintextCorpusReader(dataset, '.*txt')#here im using plaintextcorpusreader from nltk to read and save the files
 id_list = corpus.fileids()#using fileids,all the filenames in categories and subcategories are retrieved.
 len_total=len(id_list)#here the total length of files is counted.


#here i am using for loop to iterate through all the files names.Im joining to get file path.
 for i in id_list:
   var3 = "".join([dataset, "/",i]) 
   r=open(var3,"rt")
   r=var3
   #print(r)
   data=pd.read_csv(r, sep = "\t", header = None, encoding= 'unicode_escape')
   dfr=dfr.append(data)


 dfr['phrase_label']=dfr[1]+" "+dfr[2]
 dfr.columns= ['id', 'label', 'phrase', 'phrase_label']
 dfr = dfr.astype({"id": str})
 for columns in dfr.columns:
  dfr[columns] = dfr[columns].str.lower() 

 dfr = dfr.drop_duplicates('phrase_label')
 
 index_l = []
 for i in range(dfr.shape[0]):
        if dfr['label'].value_counts()[dfr.iloc[i]['label']] < 5:
            index_l.append(i)
 dfr.drop(dfr.index[index_l], inplace=True)
   

 res['Unique_phrases'] = str(len(dfr['phrase'].unique()))
 res['Unique_labels'] = str(len(dfr['label'].unique()))
 res['Unique_phrase_label_pairs'] = str(dfr.shape[0])
 df1 = pd.DataFrame(dfr['phrase'].value_counts())
 res['Phrases_with_multiple_labels'] = str(df1[df1['phrase'] > 1].shape[0])
 res['Min_examples_per_label'] = str(dfr['label'].value_counts().values.min())
 res['Max_examples_per_label'] = str(dfr['label'].value_counts().values.max())
 res['Avg_examples_per_label'] = round(dfr['label'].value_counts().mean(),2)
 res_df = res_df.append(res, ignore_index=True)

res_df = res_df.transpose()
# result_df.iloc[0:6].astype(int)

res_df.columns = ['TwADR-L', 'AskAPatient']

res_df
# Out:
#                              TwADR-L AskAPatient
# Unique_phrases                   512        2563
# Unique_labels                     76         233
# Unique_phrase_label_pairs        578        2583
# Phrases_with_multiple_labels      56          19
# Min_examples_per_label             3           3
# Max_examples_per_label            28         135
# Avg_examples_per_label          7.61       11.09

# %%
import numpy as np
from sklearn.model_selection import KFold
X1 = np.array(dfr)

kfo = KFold(n_splits = 10, shuffle = True, random_state = 0)
for train_index, test_index in kfo.split(X1):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X1[train_index], X1[test_index]
# Out:
# TRAIN: [   0    1    2 ... 4504 4505 4506] TEST: [  42   45   57   72   87  104  117  125  130  142  148  154  156  159
#   162  170  173  189  192  195  214  217  218  220  223  224  246  252
#   263  269  291  294  302  304  308  348  379  383  402  410  453  481
#   487  491  496  500  514  526  528  530  531  541  543  545  555  556
#   559  562  582  584  634  636  639  648  661  666  668  678  683  704
#   708  712  716  720  731  735  773  776  799  809  817  825  829  836
#   841  849  861  867  878  898  917  933  938  939  942  949  962  965
#   971  977  979 1001 1002 1012 1021 1065 1082 1084 1115 1116 1141 1144
#  1160 1172 1176 1182 1237 1259 1271 1275 1290 1326 1328 1336 1343 1358
#  1363 1364 1376 1385 1386 1389 1399 1410 1412 1427 1436 1448 1457 1461
#  1478 1491 1536 1553 1559 1564 1574 1581 1586 1590 1596 1601 1606 1615
#  1618 1642 1654 1657 1666 1695 1696 1697 1700 1705 1713 1738 1757 1762
#  1763 1767 1783 1819 1824 1865 1869 1872 1875 1881 1888 1895 1900 1906
# ...
